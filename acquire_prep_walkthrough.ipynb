# %% [markdown]
# # Acquire Walkthrough
# ---
#
# ## Let's import our libraries

# %%
import pandas as pd
from pandas_profiling import ProfileReport

import env
import acquire
import prep

# %% [markdown]
# ## Next let's bring in our zillow data from the SQL server
#
# ***If reproducing, run the commented code below to get the data***

# %%
query = '''
SELECT p.id, p.bathroomcnt, p.bedroomcnt, p.calculatedbathnbr, p.calculatedfinishedsquarefeet, p.fips, p.fullbathcnt, p.latitude, p.longitude, p.roomcnt, p.yearbuilt, p.taxvaluedollarcnt, ROUND((p.taxamount / p.taxvaluedollarcnt) * 100, 2) AS taxrate
FROM properties_2017 AS p
JOIN predictions_2017 AS pr USING (parcelid)
WHERE p.propertylandusetypeid IN (261, 262, 263, 264, 266, 268, 273, 276, 279)
AND pr.transactiondate BETWEEN "2017-05-01" AND '2017-06-30';
'''

url = acquire.get_url('zillow')

zillow = pd.read_sql(query, url, index_col='id')

# %% [markdown]
# * I chose the above columsn based on their lack of null values
# * Fips is included for county identifcation
# * taxrate is calculated for later use in exploration
#
# ## Now let's export is as a csv and bring it back so that we don't have to rerun the query each time.

# %%
zillow.to_csv('zillow.csv')

# %%
zillow = pd.read_csv('zillow.csv')
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 0      2061546          2.0         3.0                2.0
# 1      1834372          1.0         2.0                1.0
# 2      1923117          3.0         4.0                3.0
# 3      2121349          2.0         3.0                2.0
# 4      2093710          1.0         2.0                1.0
# ...        ...          ...         ...                ...
# 20343  2922089          2.0         2.0                2.0
# 20344  1948691          2.0         3.0                2.0
# 20345   444575          3.0         5.0                3.0
# 20346  1480299          3.0         4.0                3.0
# 20347  1092708          2.0         3.0                2.0
#
#        calculatedfinishedsquarefeet    fips  fullbathcnt    latitude  \
# 0                            1458.0  6037.0          2.0  34686163.0
# 1                            1421.0  6037.0          1.0  33999877.0
# 2                            2541.0  6059.0          3.0  33694636.0
# 3                            1650.0  6037.0          2.0  33985377.0
# 4                             693.0  6037.0          1.0  34112946.0
# ...                             ...     ...          ...         ...
# 20343                        1030.0  6037.0          2.0  34150300.0
# 20344                        1536.0  6037.0          2.0  34058178.0
# 20345                        2655.0  6059.0          3.0  33836898.0
# 20346                        2305.0  6037.0          3.0  33952368.0
# 20347                        1997.0  6037.0          2.0  33981200.0
#
#          longitude  roomcnt  yearbuilt  taxvaluedollarcnt  taxrate
# 0     -118113100.0      0.0     1970.0           136104.0     1.70
# 1     -118291863.0      0.0     1911.0            35606.0     1.53
# 2     -117912245.0      0.0     2003.0           880456.0     1.12
# 3     -118361620.0      0.0     1949.0           614000.0     1.25
# 4     -118208106.0      0.0     1921.0           274237.0     1.19
# ...            ...      ...        ...                ...      ...
# 20343 -118468000.0      0.0     1988.0           359829.0     1.22
# 20344 -117948180.0      0.0     1955.0           297097.0     1.18
# 20345 -117801369.0      0.0     1994.0           746963.0     1.08
# 20346 -118441155.0      0.0     1949.0           579047.0     1.21
# 20347 -118437000.0      0.0     1966.0           630933.0     1.20
#
# [20348 rows x 13 columns]

# %% [markdown]
# ## Next let's add the county by using the fips number as the identifier

# %%
def label_county(row):
    if row['fips'] == 6037:
        return 'Los Angeles'
    elif row['fips'] == 6059:
        return 'Orange'
    elif row['fips'] == 6111:
        return 'Ventura'

# %%
zillow['County'] = zillow.apply(lambda row: label_county(row), axis=1)
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 0      2061546          2.0         3.0                2.0
# 1      1834372          1.0         2.0                1.0
# 2      1923117          3.0         4.0                3.0
# 3      2121349          2.0         3.0                2.0
# 4      2093710          1.0         2.0                1.0
# ...        ...          ...         ...                ...
# 20343  2922089          2.0         2.0                2.0
# 20344  1948691          2.0         3.0                2.0
# 20345   444575          3.0         5.0                3.0
# 20346  1480299          3.0         4.0                3.0
# 20347  1092708          2.0         3.0                2.0
#
#        calculatedfinishedsquarefeet    fips  fullbathcnt    latitude  \
# 0                            1458.0  6037.0          2.0  34686163.0
# 1                            1421.0  6037.0          1.0  33999877.0
# 2                            2541.0  6059.0          3.0  33694636.0
# 3                            1650.0  6037.0          2.0  33985377.0
# 4                             693.0  6037.0          1.0  34112946.0
# ...                             ...     ...          ...         ...
# 20343                        1030.0  6037.0          2.0  34150300.0
# 20344                        1536.0  6037.0          2.0  34058178.0
# 20345                        2655.0  6059.0          3.0  33836898.0
# 20346                        2305.0  6037.0          3.0  33952368.0
# 20347                        1997.0  6037.0          2.0  33981200.0
#
#          longitude  roomcnt  yearbuilt  taxvaluedollarcnt  taxrate  \
# 0     -118113100.0      0.0     1970.0           136104.0     1.70
# 1     -118291863.0      0.0     1911.0            35606.0     1.53
# 2     -117912245.0      0.0     2003.0           880456.0     1.12
# 3     -118361620.0      0.0     1949.0           614000.0     1.25
# 4     -118208106.0      0.0     1921.0           274237.0     1.19
# ...            ...      ...        ...                ...      ...
# 20343 -118468000.0      0.0     1988.0           359829.0     1.22
# 20344 -117948180.0      0.0     1955.0           297097.0     1.18
# 20345 -117801369.0      0.0     1994.0           746963.0     1.08
# 20346 -118441155.0      0.0     1949.0           579047.0     1.21
# 20347 -118437000.0      0.0     1966.0           630933.0     1.20
#
#             County
# 0      Los Angeles
# 1      Los Angeles
# 2           Orange
# 3      Los Angeles
# 4      Los Angeles
# ...            ...
# 20343  Los Angeles
# 20344  Los Angeles
# 20345       Orange
# 20346  Los Angeles
# 20347  Los Angeles
#
# [20348 rows x 14 columns]

# %%
zillow['State'] = 'CA'
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 0      2061546          2.0         3.0                2.0
# 1      1834372          1.0         2.0                1.0
# 2      1923117          3.0         4.0                3.0
# 3      2121349          2.0         3.0                2.0
# 4      2093710          1.0         2.0                1.0
# ...        ...          ...         ...                ...
# 20343  2922089          2.0         2.0                2.0
# 20344  1948691          2.0         3.0                2.0
# 20345   444575          3.0         5.0                3.0
# 20346  1480299          3.0         4.0                3.0
# 20347  1092708          2.0         3.0                2.0
#
#        calculatedfinishedsquarefeet    fips  fullbathcnt    latitude  \
# 0                            1458.0  6037.0          2.0  34686163.0
# 1                            1421.0  6037.0          1.0  33999877.0
# 2                            2541.0  6059.0          3.0  33694636.0
# 3                            1650.0  6037.0          2.0  33985377.0
# 4                             693.0  6037.0          1.0  34112946.0
# ...                             ...     ...          ...         ...
# 20343                        1030.0  6037.0          2.0  34150300.0
# 20344                        1536.0  6037.0          2.0  34058178.0
# 20345                        2655.0  6059.0          3.0  33836898.0
# 20346                        2305.0  6037.0          3.0  33952368.0
# 20347                        1997.0  6037.0          2.0  33981200.0
#
#          longitude  roomcnt  yearbuilt  taxvaluedollarcnt  taxrate  \
# 0     -118113100.0      0.0     1970.0           136104.0     1.70
# 1     -118291863.0      0.0     1911.0            35606.0     1.53
# 2     -117912245.0      0.0     2003.0           880456.0     1.12
# 3     -118361620.0      0.0     1949.0           614000.0     1.25
# 4     -118208106.0      0.0     1921.0           274237.0     1.19
# ...            ...      ...        ...                ...      ...
# 20343 -118468000.0      0.0     1988.0           359829.0     1.22
# 20344 -117948180.0      0.0     1955.0           297097.0     1.18
# 20345 -117801369.0      0.0     1994.0           746963.0     1.08
# 20346 -118441155.0      0.0     1949.0           579047.0     1.21
# 20347 -118437000.0      0.0     1966.0           630933.0     1.20
#
#             County State
# 0      Los Angeles    CA
# 1      Los Angeles    CA
# 2           Orange    CA
# 3      Los Angeles    CA
# 4      Los Angeles    CA
# ...            ...   ...
# 20343  Los Angeles    CA
# 20344  Los Angeles    CA
# 20345       Orange    CA
# 20346  Los Angeles    CA
# 20347  Los Angeles    CA
#
# [20348 rows x 15 columns]

# %% [markdown]
# ## Now let's get a quick look at the data

# %%
zillow.describe()
# Out:
#                  id   bathroomcnt    bedroomcnt  calculatedbathnbr  \
# count  2.034800e+04  20348.000000  20348.000000       20278.000000
# mean   1.510457e+06      2.285507      3.021181           2.292756
# std    8.598606e+05      0.957624      1.029851           0.950579
# min    3.490000e+02      0.000000      0.000000           1.000000
# 25%    7.746850e+05      2.000000      2.000000           2.000000
# 50%    1.525712e+06      2.000000      3.000000           2.000000
# 75%    2.253321e+06      3.000000      4.000000           3.000000
# max    2.982274e+06     11.000000     12.000000          11.000000
#
#        calculatedfinishedsquarefeet          fips   fullbathcnt      latitude  \
# count                  20303.000000  20348.000000  20278.000000  2.034800e+04
# mean                    1776.690391   6049.483782      2.219795  3.400384e+07
# std                      936.896616     20.960930      0.931478  2.709476e+05
# min                      242.000000   6037.000000      1.000000  3.334085e+07
# 25%                     1176.000000   6037.000000      2.000000  3.380028e+07
# 50%                     1536.000000   6037.000000      2.000000  3.401814e+07
# 75%                     2103.000000   6059.000000      3.000000  3.417736e+07
# max                    15450.000000   6111.000000     11.000000  3.477966e+07
#
#           longitude       roomcnt     yearbuilt  taxvaluedollarcnt  \
# count  2.034800e+04  20348.000000  20286.000000       2.034800e+04
# mean  -1.181961e+08      1.593228   1969.377452       5.056470e+05
# std    3.631901e+05      2.919491     23.276860       6.586031e+05
# min   -1.193883e+08      0.000000   1878.000000       1.050400e+04
# 25%   -1.184184e+08      0.000000   1954.000000       2.107685e+05
# 50%   -1.181670e+08      0.000000   1970.000000       3.670000e+05
# 75%   -1.179129e+08      0.000000   1987.000000       5.895145e+05
# max   -1.175554e+08     14.000000   2015.000000       2.385837e+07
#
#             taxrate
# count  20347.000000
# mean       1.315918
# std        0.602459
# min        0.010000
# 25%        1.160000
# 50%        1.220000
# 75%        1.340000
# max       45.290000

# %% [markdown]
# We can see that their are some zero in bedroom and bathroom count so we will probably go ahead and get rid of those

# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20348 entries, 0 to 20347
# Data columns (total 15 columns):
# id                              20348 non-null int64
# bathroomcnt                     20348 non-null float64
# bedroomcnt                      20348 non-null float64
# calculatedbathnbr               20278 non-null float64
# calculatedfinishedsquarefeet    20303 non-null float64
# fips                            20348 non-null float64
# fullbathcnt                     20278 non-null float64
# latitude                        20348 non-null float64
# longitude                       20348 non-null float64
# roomcnt                         20348 non-null float64
# yearbuilt                       20286 non-null float64
# taxvaluedollarcnt               20348 non-null float64
# taxrate                         20347 non-null float64
# County                          20348 non-null object
# State                           20348 non-null object
# dtypes: float64(12), int64(1), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Now let's build a function in the acquire file that gets the data

# %%
zillow = acquire.get_data()
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 0      2061546          2.0         3.0                2.0
# 1      1834372          1.0         2.0                1.0
# 2      1923117          3.0         4.0                3.0
# 3      2121349          2.0         3.0                2.0
# 4      2093710          1.0         2.0                1.0
# ...        ...          ...         ...                ...
# 20343  2922089          2.0         2.0                2.0
# 20344  1948691          2.0         3.0                2.0
# 20345   444575          3.0         5.0                3.0
# 20346  1480299          3.0         4.0                3.0
# 20347  1092708          2.0         3.0                2.0
#
#        calculatedfinishedsquarefeet    fips  fullbathcnt    latitude  \
# 0                            1458.0  6037.0          2.0  34686163.0
# 1                            1421.0  6037.0          1.0  33999877.0
# 2                            2541.0  6059.0          3.0  33694636.0
# 3                            1650.0  6037.0          2.0  33985377.0
# 4                             693.0  6037.0          1.0  34112946.0
# ...                             ...     ...          ...         ...
# 20343                        1030.0  6037.0          2.0  34150300.0
# 20344                        1536.0  6037.0          2.0  34058178.0
# 20345                        2655.0  6059.0          3.0  33836898.0
# 20346                        2305.0  6037.0          3.0  33952368.0
# 20347                        1997.0  6037.0          2.0  33981200.0
#
#          longitude  roomcnt  yearbuilt  taxvaluedollarcnt  taxrate  \
# 0     -118113100.0      0.0     1970.0           136104.0     1.70
# 1     -118291863.0      0.0     1911.0            35606.0     1.53
# 2     -117912245.0      0.0     2003.0           880456.0     1.12
# 3     -118361620.0      0.0     1949.0           614000.0     1.25
# 4     -118208106.0      0.0     1921.0           274237.0     1.19
# ...            ...      ...        ...                ...      ...
# 20343 -118468000.0      0.0     1988.0           359829.0     1.22
# 20344 -117948180.0      0.0     1955.0           297097.0     1.18
# 20345 -117801369.0      0.0     1994.0           746963.0     1.08
# 20346 -118441155.0      0.0     1949.0           579047.0     1.21
# 20347 -118437000.0      0.0     1966.0           630933.0     1.20
#
#             County State
# 0      Los Angeles    CA
# 1      Los Angeles    CA
# 2           Orange    CA
# 3      Los Angeles    CA
# 4      Los Angeles    CA
# ...            ...   ...
# 20343  Los Angeles    CA
# 20344  Los Angeles    CA
# 20345       Orange    CA
# 20346  Los Angeles    CA
# 20347  Los Angeles    CA
#
# [20348 rows x 15 columns]

# %% [markdown]
# # Preparation Walkthrough
#
# ## First let's check for duplicates

# %%
zillow[zillow.duplicated(keep=False)]
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 93     2011553          1.5         2.0                1.5
# 94     2011553          1.5         2.0                1.5
# 1876   2456793          1.0         2.0                1.0
# 1877   2456793          1.0         2.0                1.0
# 1881    159239          3.0         2.0                3.0
# 1882    159239          3.0         2.0                3.0
# 2565   2415168          4.0         4.0                4.0
# 2566   2415168          4.0         4.0                4.0
# 6773   2595690          3.0         4.0                3.0
# 6774   2595690          3.0         4.0                3.0
# 6866   2353255          2.0         4.0                2.0
# 6867   2353255          2.0         4.0                2.0
# 11380  1968735          6.0        12.0                6.0
# 11381  1968735          6.0        12.0                6.0
# 11382  1968735          6.0        12.0                6.0
#
#        calculatedfinishedsquarefeet    fips  fullbathcnt    latitude  \
# 93                           1190.0  6059.0          1.0  33636000.0
# 94                           1190.0  6059.0          1.0  33636000.0
# 1876                         1025.0  6059.0          1.0  33707862.0
# 1877                         1025.0  6059.0          1.0  33707862.0
# 1881                         1149.0  6037.0          3.0  34024472.0
# 1882                         1149.0  6037.0          3.0  34024472.0
# 2565                         2459.0  6111.0          4.0  34245590.0
# 2566                         2459.0  6111.0          4.0  34245590.0
# 6773                         1816.0  6111.0          3.0  34213981.0
# 6774                         1816.0  6111.0          3.0  34213981.0
# 6866                         2126.0  6059.0          2.0  33753200.0
# 6867                         2126.0  6059.0          2.0  33753200.0
# 11380                        8469.0  6037.0          6.0  34072327.0
# 11381                        8469.0  6037.0          6.0  34072327.0
# 11382                        8469.0  6037.0          6.0  34072327.0
#
#          longitude  roomcnt  yearbuilt  taxvaluedollarcnt  taxrate  \
# 93    -117679000.0      4.0     1979.0           357000.0     1.06
# 94    -117679000.0      4.0     1979.0           357000.0     1.06
# 1876  -117980009.0      4.0     1940.0            48107.0     1.79
# 1877  -117980009.0      4.0     1940.0            48107.0     1.79
# 1881  -117766183.0      0.0     1985.0           218619.0     1.41
# 1882  -117766183.0      0.0     1985.0           218619.0     1.41
# 2565  -119169692.0      7.0     2007.0           479000.0     2.56
# 2566  -119169692.0      7.0     2007.0           479000.0     2.56
# 6773  -118857003.0      7.0     1960.0           350701.0     1.08
# 6774  -118857003.0      7.0     1960.0           350701.0     1.08
# 6866  -117829644.0      8.0     1966.0            98473.0     1.46
# 6867  -117829644.0      8.0     1966.0            98473.0     1.46
# 11380 -118298778.0      0.0     1909.0          2485282.0     1.22
# 11381 -118298778.0      0.0     1909.0          2485282.0     1.22
# 11382 -118298778.0      0.0     1909.0          2485282.0     1.22
#
#             County State
# 93          Orange    CA
# 94          Orange    CA
# 1876        Orange    CA
# 1877        Orange    CA
# 1881   Los Angeles    CA
# 1882   Los Angeles    CA
# 2565       Ventura    CA
# 2566       Ventura    CA
# 6773       Ventura    CA
# 6774       Ventura    CA
# 6866        Orange    CA
# 6867        Orange    CA
# 11380  Los Angeles    CA
# 11381  Los Angeles    CA
# 11382  Los Angeles    CA

# %% [markdown]
# ### There are a few duplicates but the info is identical for each so let's get rid of the second duplicate for each

# %%
print(zillow.shape)
zillow = zillow.drop_duplicates()
print(zillow.shape)
# Out:
# (20348, 15)
# (20340, 15)

# %% [markdown]
# ## Let's see if we have any dtype or null issues

# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20340 entries, 0 to 20347
# Data columns (total 15 columns):
# id                              20340 non-null int64
# bathroomcnt                     20340 non-null float64
# bedroomcnt                      20340 non-null float64
# calculatedbathnbr               20270 non-null float64
# calculatedfinishedsquarefeet    20295 non-null float64
# fips                            20340 non-null float64
# fullbathcnt                     20270 non-null float64
# latitude                        20340 non-null float64
# longitude                       20340 non-null float64
# roomcnt                         20340 non-null float64
# yearbuilt                       20278 non-null float64
# taxvaluedollarcnt               20340 non-null float64
# taxrate                         20339 non-null float64
# County                          20340 non-null object
# State                           20340 non-null object
# dtypes: float64(12), int64(1), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# ### So there are missing values some columns, but not enough to make a difference so let's just drop them for now

# %%
print(zillow.shape)
zillow = zillow.dropna()
print(zillow.shape)
# Out:
# (20340, 15)
# (20251, 15)

# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20251 entries, 0 to 20347
# Data columns (total 15 columns):
# id                              20251 non-null int64
# bathroomcnt                     20251 non-null float64
# bedroomcnt                      20251 non-null float64
# calculatedbathnbr               20251 non-null float64
# calculatedfinishedsquarefeet    20251 non-null float64
# fips                            20251 non-null float64
# fullbathcnt                     20251 non-null float64
# latitude                        20251 non-null float64
# longitude                       20251 non-null float64
# roomcnt                         20251 non-null float64
# yearbuilt                       20251 non-null float64
# taxvaluedollarcnt               20251 non-null float64
# taxrate                         20251 non-null float64
# County                          20251 non-null object
# State                           20251 non-null object
# dtypes: float64(12), int64(1), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# ### Also let's make sure columns that can be ints are changed

# %%
(zillow.taxvaluedollarcnt % 1 != 0).sum()
# Out:
# 0

# %%
zillow.bedroomcnt = zillow.bedroomcnt.astype('int')
zillow.calculatedfinishedsquarefeet = zillow.calculatedfinishedsquarefeet.astype('int')
zillow.fullbathcnt = zillow.fullbathcnt.astype('int')
zillow.yearbuilt = zillow.yearbuilt.astype('int')
zillow.taxvaluedollarcnt = zillow.taxvaluedollarcnt.astype('int')
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 0      2061546          2.0           3                2.0
# 1      1834372          1.0           2                1.0
# 2      1923117          3.0           4                3.0
# 3      2121349          2.0           3                2.0
# 4      2093710          1.0           2                1.0
# ...        ...          ...         ...                ...
# 20343  2922089          2.0           2                2.0
# 20344  1948691          2.0           3                2.0
# 20345   444575          3.0           5                3.0
# 20346  1480299          3.0           4                3.0
# 20347  1092708          2.0           3                2.0
#
#        calculatedfinishedsquarefeet    fips  fullbathcnt    latitude  \
# 0                              1458  6037.0            2  34686163.0
# 1                              1421  6037.0            1  33999877.0
# 2                              2541  6059.0            3  33694636.0
# 3                              1650  6037.0            2  33985377.0
# 4                               693  6037.0            1  34112946.0
# ...                             ...     ...          ...         ...
# 20343                          1030  6037.0            2  34150300.0
# 20344                          1536  6037.0            2  34058178.0
# 20345                          2655  6059.0            3  33836898.0
# 20346                          2305  6037.0            3  33952368.0
# 20347                          1997  6037.0            2  33981200.0
#
#          longitude  roomcnt  yearbuilt  taxvaluedollarcnt  taxrate  \
# 0     -118113100.0      0.0       1970             136104     1.70
# 1     -118291863.0      0.0       1911              35606     1.53
# 2     -117912245.0      0.0       2003             880456     1.12
# 3     -118361620.0      0.0       1949             614000     1.25
# 4     -118208106.0      0.0       1921             274237     1.19
# ...            ...      ...        ...                ...      ...
# 20343 -118468000.0      0.0       1988             359829     1.22
# 20344 -117948180.0      0.0       1955             297097     1.18
# 20345 -117801369.0      0.0       1994             746963     1.08
# 20346 -118441155.0      0.0       1949             579047     1.21
# 20347 -118437000.0      0.0       1966             630933     1.20
#
#             County State
# 0      Los Angeles    CA
# 1      Los Angeles    CA
# 2           Orange    CA
# 3      Los Angeles    CA
# 4      Los Angeles    CA
# ...            ...   ...
# 20343  Los Angeles    CA
# 20344  Los Angeles    CA
# 20345       Orange    CA
# 20346  Los Angeles    CA
# 20347  Los Angeles    CA
#
# [20251 rows x 15 columns]

# %% [markdown]
# ## We have don't need the fips and room count doesn't seem useful now either so let's get rid of that

# %%
zillow = zillow.drop(columns=['fips', 'roomcnt'])

# %% [markdown]
# ## Let's also clarify the names of some of the columns

# %%
zillow = zillow.rename(columns={'calculatedfinishedsquarefeet': 'squarefeet', 'Name': 'County'})
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  squarefeet  \
# 0      2061546          2.0           3                2.0        1458
# 1      1834372          1.0           2                1.0        1421
# 2      1923117          3.0           4                3.0        2541
# 3      2121349          2.0           3                2.0        1650
# 4      2093710          1.0           2                1.0         693
# ...        ...          ...         ...                ...         ...
# 20343  2922089          2.0           2                2.0        1030
# 20344  1948691          2.0           3                2.0        1536
# 20345   444575          3.0           5                3.0        2655
# 20346  1480299          3.0           4                3.0        2305
# 20347  1092708          2.0           3                2.0        1997
#
#        fullbathcnt    latitude    longitude  yearbuilt  taxvaluedollarcnt  \
# 0                2  34686163.0 -118113100.0       1970             136104
# 1                1  33999877.0 -118291863.0       1911              35606
# 2                3  33694636.0 -117912245.0       2003             880456
# 3                2  33985377.0 -118361620.0       1949             614000
# 4                1  34112946.0 -118208106.0       1921             274237
# ...            ...         ...          ...        ...                ...
# 20343            2  34150300.0 -118468000.0       1988             359829
# 20344            2  34058178.0 -117948180.0       1955             297097
# 20345            3  33836898.0 -117801369.0       1994             746963
# 20346            3  33952368.0 -118441155.0       1949             579047
# 20347            2  33981200.0 -118437000.0       1966             630933
#
#        taxrate       County State
# 0         1.70  Los Angeles    CA
# 1         1.53  Los Angeles    CA
# 2         1.12       Orange    CA
# 3         1.25  Los Angeles    CA
# 4         1.19  Los Angeles    CA
# ...        ...          ...   ...
# 20343     1.22  Los Angeles    CA
# 20344     1.18  Los Angeles    CA
# 20345     1.08       Orange    CA
# 20346     1.21  Los Angeles    CA
# 20347     1.20  Los Angeles    CA
#
# [20251 rows x 13 columns]

# %% [markdown]
# ## The latitude and longitude are whole numbers so lets change those.

# %%
zillow.latitude = zillow.latitude / 1000000
zillow.longitude = zillow.longitude / 1000000
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  squarefeet  \
# 0      2061546          2.0           3                2.0        1458
# 1      1834372          1.0           2                1.0        1421
# 2      1923117          3.0           4                3.0        2541
# 3      2121349          2.0           3                2.0        1650
# 4      2093710          1.0           2                1.0         693
# ...        ...          ...         ...                ...         ...
# 20343  2922089          2.0           2                2.0        1030
# 20344  1948691          2.0           3                2.0        1536
# 20345   444575          3.0           5                3.0        2655
# 20346  1480299          3.0           4                3.0        2305
# 20347  1092708          2.0           3                2.0        1997
#
#        fullbathcnt   latitude   longitude  yearbuilt  taxvaluedollarcnt  \
# 0                2  34.686163 -118.113100       1970             136104
# 1                1  33.999877 -118.291863       1911              35606
# 2                3  33.694636 -117.912245       2003             880456
# 3                2  33.985377 -118.361620       1949             614000
# 4                1  34.112946 -118.208106       1921             274237
# ...            ...        ...         ...        ...                ...
# 20343            2  34.150300 -118.468000       1988             359829
# 20344            2  34.058178 -117.948180       1955             297097
# 20345            3  33.836898 -117.801369       1994             746963
# 20346            3  33.952368 -118.441155       1949             579047
# 20347            2  33.981200 -118.437000       1966             630933
#
#        taxrate       County State
# 0         1.70  Los Angeles    CA
# 1         1.53  Los Angeles    CA
# 2         1.12       Orange    CA
# 3         1.25  Los Angeles    CA
# 4         1.19  Los Angeles    CA
# ...        ...          ...   ...
# 20343     1.22  Los Angeles    CA
# 20344     1.18  Los Angeles    CA
# 20345     1.08       Orange    CA
# 20346     1.21  Los Angeles    CA
# 20347     1.20  Los Angeles    CA
#
# [20251 rows x 13 columns]

# %% [markdown]
# ## Now let's make a function in our prepare file that gets the data for us and cleans it.

# %%
prep.acquire_and_prep_data()
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedbathnbr  squarefeet  \
# 0      2061546          2.0           3                2.0        1458
# 1      1834372          1.0           2                1.0        1421
# 2      1923117          3.0           4                3.0        2541
# 3      2121349          2.0           3                2.0        1650
# 4      2093710          1.0           2                1.0         693
# ...        ...          ...         ...                ...         ...
# 20343  2922089          2.0           2                2.0        1030
# 20344  1948691          2.0           3                2.0        1536
# 20345   444575          3.0           5                3.0        2655
# 20346  1480299          3.0           4                3.0        2305
# 20347  1092708          2.0           3                2.0        1997
#
#        fullbathcnt   latitude   longitude  roomcnt  yearbuilt  \
# 0                2  34.686163 -118.113100      0.0       1970
# 1                1  33.999877 -118.291863      0.0       1911
# 2                3  33.694636 -117.912245      0.0       2003
# 3                2  33.985377 -118.361620      0.0       1949
# 4                1  34.112946 -118.208106      0.0       1921
# ...            ...        ...         ...      ...        ...
# 20343            2  34.150300 -118.468000      0.0       1988
# 20344            2  34.058178 -117.948180      0.0       1955
# 20345            3  33.836898 -117.801369      0.0       1994
# 20346            3  33.952368 -118.441155      0.0       1949
# 20347            2  33.981200 -118.437000      0.0       1966
#
#        taxvaluedollarcnt  taxrate       County State
# 0                 136104     1.70  Los Angeles    CA
# 1                  35606     1.53  Los Angeles    CA
# 2                 880456     1.12       Orange    CA
# 3                 614000     1.25  Los Angeles    CA
# 4                 274237     1.19  Los Angeles    CA
# ...                  ...      ...          ...   ...
# 20343             359829     1.22  Los Angeles    CA
# 20344             297097     1.18  Los Angeles    CA
# 20345             746963     1.08       Orange    CA
# 20346             579047     1.21  Los Angeles    CA
# 20347             630933     1.20  Los Angeles    CA
#
# [20251 rows x 14 columns]
