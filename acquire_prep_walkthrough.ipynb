# %% [markdown]
# # Acquire Walkthrough
# ---
#
# ## Lets import our libraries

# %%
import pandas as pd
from pandas_profiling import ProfileReport

import env
import acquire
import prep

# %% [markdown]
# ## Next lets bring in our zillow data from the SQL server
#
# ***If reproducing, run the commented code below***

# %%
# query = '''
# SELECT p.id, p.bathroomcnt, p.bedroomcnt, p.calculatedfinishedsquarefeet, 
#     p.fips, p.taxvaluedollarcnt, p.taxamount, 
#     ROUND((p.taxamount / p.taxvaluedollarcnt) * 100, 2) AS taxrate
# FROM properties_2017 AS p
# JOIN predictions_2017 AS pr USING (parcelid)
# WHERE p.propertylandusetypeid IN (261, 262, 263, 264, 266, 268, 273, 276, 279)
# AND pr.transactiondate BETWEEN "2017-05-01" AND '2017-06-30';
# '''

# url = acquire.get_url('zillow')

# zillow = pd.read_sql(query, url, index_col='id')

# %% [markdown]
# ## Now lets export is as a csv and bring it back so that we don't have to rerun the query each time.

# %%
# zillow.to_csv('zillow.csv')

# %%
zillow = pd.read_csv('zillow.csv')
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0      2061546          2.0         3.0                        1458.0  6037.0
# 1      1834372          1.0         2.0                        1421.0  6037.0
# 2      1923117          3.0         4.0                        2541.0  6059.0
# 3      2121349          2.0         3.0                        1650.0  6037.0
# 4      2093710          1.0         2.0                         693.0  6037.0
# ...        ...          ...         ...                           ...     ...
# 20343  2922089          2.0         2.0                        1030.0  6037.0
# 20344  1948691          2.0         3.0                        1536.0  6037.0
# 20345   444575          3.0         5.0                        2655.0  6059.0
# 20346  1480299          3.0         4.0                        2305.0  6037.0
# 20347  1092708          2.0         3.0                        1997.0  6037.0
#
#        taxvaluedollarcnt  taxamount  taxrate
# 0               136104.0    2319.90     1.70
# 1                35606.0     543.69     1.53
# 2               880456.0    9819.72     1.12
# 3               614000.0    7673.19     1.25
# 4               274237.0    3267.47     1.19
# ...                  ...        ...      ...
# 20343           359829.0    4378.59     1.22
# 20344           297097.0    3519.78     1.18
# 20345           746963.0    8065.50     1.08
# 20346           579047.0    6996.21     1.21
# 20347           630933.0    7587.79     1.20
#
# [20348 rows x 8 columns]

# %% [markdown]
# ## Great, now we need to bring in some outside data so that we can identify the county by the fips column in zillow
#
# FIPS data was copied from this location: https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/home/?cid=nrcs143_013697
#
# ***If reproducing, run the below commented code to create the file in your directory***

# %%
#commented after it ran
#fips = pd.read_clipboard().set_index('FIPS')

# %%
#commented after it ran
#fips.to_csv('fips.csv')

# %%
FIPS = pd.read_csv('fips.csv')
FIPS
# Out:
#        FIPS        Name State
# 0      1001     Autauga    AL
# 1      1003     Baldwin    AL
# 2      1005     Barbour    AL
# 3      1007        Bibb    AL
# 4      1009      Blount    AL
# ...     ...         ...   ...
# 3227  72151     Yabucoa    PR
# 3228  72153       Yauco    PR
# 3229  78010   St. Croix    VI
# 3230  78020    St. John    VI
# 3231  78030  St. Thomas    VI
#
# [3232 rows x 3 columns]

# %% [markdown]
# ## Now lets merge the tables so we have it all on one

# %%
zillow = zillow.merge(FIPS, left_on='fips', right_on='FIPS')

# %%
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0      2061546          2.0         3.0                        1458.0  6037.0
# 1      1834372          1.0         2.0                        1421.0  6037.0
# 2      2121349          2.0         3.0                        1650.0  6037.0
# 3      2093710          1.0         2.0                         693.0  6037.0
# 4       496818          0.0         0.0                        1378.0  6037.0
# ...        ...          ...         ...                           ...     ...
# 20343  1624472          3.0         3.0                        2632.0  6111.0
# 20344   997928          3.0         4.0                        2734.0  6111.0
# 20345   849307          2.5         4.0                        2314.0  6111.0
# 20346  2416171          2.0         2.0                        1178.0  6111.0
# 20347  2163429          2.0         3.0                        1278.0  6111.0
#
#        taxvaluedollarcnt  taxamount  taxrate  FIPS         Name State
# 0               136104.0    2319.90     1.70  6037  Los Angeles    CA
# 1                35606.0     543.69     1.53  6037  Los Angeles    CA
# 2               614000.0    7673.19     1.25  6037  Los Angeles    CA
# 3               274237.0    3267.47     1.19  6037  Los Angeles    CA
# 4               168828.0    2135.39     1.26  6037  Los Angeles    CA
# ...                  ...        ...      ...   ...          ...   ...
# 20343           795992.0    8449.92     1.06  6111      Ventura    CA
# 20344           897000.0    9585.08     1.07  6111      Ventura    CA
# 20345           485364.0    9549.08     1.97  6111      Ventura    CA
# 20346           169908.0    1779.86     1.05  6111      Ventura    CA
# 20347           468000.0    5396.08     1.15  6111      Ventura    CA
#
# [20348 rows x 11 columns]

# %% [markdown]
# ## Now lets get a quick look at the data

# %%
zillow.describe()
# Out:
#                  id   bathroomcnt    bedroomcnt  calculatedfinishedsquarefeet  \
# count  2.034800e+04  20348.000000  20348.000000                  20303.000000
# mean   1.510457e+06      2.285507      3.021181                   1776.690391
# std    8.598606e+05      0.957624      1.029851                    936.896616
# min    3.490000e+02      0.000000      0.000000                    242.000000
# 25%    7.746850e+05      2.000000      2.000000                   1176.000000
# 50%    1.525712e+06      2.000000      3.000000                   1536.000000
# 75%    2.253321e+06      3.000000      4.000000                   2103.000000
# max    2.982274e+06     11.000000     12.000000                  15450.000000
#
#                fips  taxvaluedollarcnt      taxamount       taxrate  \
# count  20348.000000       2.034800e+04   20347.000000  20347.000000
# mean    6049.483782       5.056470e+05    6158.269147      1.315918
# std       20.960930       6.586031e+05    7642.769432      0.602459
# min     6037.000000       1.050400e+04      19.920000      0.010000
# 25%     6037.000000       2.107685e+05    2736.860000      1.160000
# 50%     6037.000000       3.670000e+05    4525.660000      1.220000
# 75%     6059.000000       5.895145e+05    7132.225000      1.340000
# max     6111.000000       2.385837e+07  276797.830000     45.290000
#
#                FIPS
# count  20348.000000
# mean    6049.483782
# std       20.960930
# min     6037.000000
# 25%     6037.000000
# 50%     6037.000000
# 75%     6059.000000
# max     6111.000000

# %% [markdown]
# We can see that their are some zero in bedroom and bathroom count so we will probably go ahead and get rid of those

# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20348 entries, 0 to 20347
# Data columns (total 11 columns):
# id                              20348 non-null int64
# bathroomcnt                     20348 non-null float64
# bedroomcnt                      20348 non-null float64
# calculatedfinishedsquarefeet    20303 non-null float64
# fips                            20348 non-null float64
# taxvaluedollarcnt               20348 non-null float64
# taxamount                       20347 non-null float64
# taxrate                         20347 non-null float64
# FIPS                            20348 non-null int64
# Name                            20348 non-null object
# State                           20348 non-null object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Now lets build a function that reads these csvs

# %%
zillow = acquire.get_data()
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0      2061546          2.0         3.0                        1458.0  6037.0
# 1      1834372          1.0         2.0                        1421.0  6037.0
# 2      2121349          2.0         3.0                        1650.0  6037.0
# 3      2093710          1.0         2.0                         693.0  6037.0
# 4       496818          0.0         0.0                        1378.0  6037.0
# ...        ...          ...         ...                           ...     ...
# 20343  1624472          3.0         3.0                        2632.0  6111.0
# 20344   997928          3.0         4.0                        2734.0  6111.0
# 20345   849307          2.5         4.0                        2314.0  6111.0
# 20346  2416171          2.0         2.0                        1178.0  6111.0
# 20347  2163429          2.0         3.0                        1278.0  6111.0
#
#        taxvaluedollarcnt  taxamount  taxrate  FIPS         Name State
# 0               136104.0    2319.90     1.70  6037  Los Angeles    CA
# 1                35606.0     543.69     1.53  6037  Los Angeles    CA
# 2               614000.0    7673.19     1.25  6037  Los Angeles    CA
# 3               274237.0    3267.47     1.19  6037  Los Angeles    CA
# 4               168828.0    2135.39     1.26  6037  Los Angeles    CA
# ...                  ...        ...      ...   ...          ...   ...
# 20343           795992.0    8449.92     1.06  6111      Ventura    CA
# 20344           897000.0    9585.08     1.07  6111      Ventura    CA
# 20345           485364.0    9549.08     1.97  6111      Ventura    CA
# 20346           169908.0    1779.86     1.05  6111      Ventura    CA
# 20347           468000.0    5396.08     1.15  6111      Ventura    CA
#
# [20348 rows x 11 columns]

# %% [markdown]
# # Preparation Walkthrough
#
# ## First lets check for duplicates

# %%
zillow[zillow.duplicated(keep=False)]
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 1219    159239          3.0         2.0                        1149.0  6037.0
# 1220    159239          3.0         2.0                        1149.0  6037.0
# 7194   1968735          6.0        12.0                        8469.0  6037.0
# 7195   1968735          6.0        12.0                        8469.0  6037.0
# 7196   1968735          6.0        12.0                        8469.0  6037.0
# 12841  2011553          1.5         2.0                        1190.0  6059.0
# 12842  2011553          1.5         2.0                        1190.0  6059.0
# 13317  2456793          1.0         2.0                        1025.0  6059.0
# 13318  2456793          1.0         2.0                        1025.0  6059.0
# 14821  2353255          2.0         4.0                        2126.0  6059.0
# 14822  2353255          2.0         4.0                        2126.0  6059.0
# 18845  2415168          4.0         4.0                        2459.0  6111.0
# 18846  2415168          4.0         4.0                        2459.0  6111.0
# 19175  2595690          3.0         4.0                        1816.0  6111.0
# 19176  2595690          3.0         4.0                        1816.0  6111.0
#
#        taxvaluedollarcnt  taxamount  taxrate  FIPS         Name State
# 1219            218619.0    3074.84     1.41  6037  Los Angeles    CA
# 1220            218619.0    3074.84     1.41  6037  Los Angeles    CA
# 7194           2485282.0   30342.87     1.22  6037  Los Angeles    CA
# 7195           2485282.0   30342.87     1.22  6037  Los Angeles    CA
# 7196           2485282.0   30342.87     1.22  6037  Los Angeles    CA
# 12841           357000.0    3772.90     1.06  6059       Orange    CA
# 12842           357000.0    3772.90     1.06  6059       Orange    CA
# 13317            48107.0     862.90     1.79  6059       Orange    CA
# 13318            48107.0     862.90     1.79  6059       Orange    CA
# 14821            98473.0    1435.68     1.46  6059       Orange    CA
# 14822            98473.0    1435.68     1.46  6059       Orange    CA
# 18845           479000.0   12285.88     2.56  6111      Ventura    CA
# 18846           479000.0   12285.88     2.56  6111      Ventura    CA
# 19175           350701.0    3776.38     1.08  6111      Ventura    CA
# 19176           350701.0    3776.38     1.08  6111      Ventura    CA

# %% [markdown]
# ### There are a few duplicates but the info is identical for each so lets get rid of the second duplicate for each

# %%
zillow = zillow.drop_duplicates()

# %% [markdown]
# ## Lets see if we have any dtype or null issues

# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20340 entries, 0 to 20347
# Data columns (total 11 columns):
# id                              20340 non-null int64
# bathroomcnt                     20340 non-null float64
# bedroomcnt                      20340 non-null float64
# calculatedfinishedsquarefeet    20295 non-null float64
# fips                            20340 non-null float64
# taxvaluedollarcnt               20340 non-null float64
# taxamount                       20339 non-null float64
# taxrate                         20339 non-null float64
# FIPS                            20340 non-null int64
# Name                            20340 non-null object
# State                           20340 non-null object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# ### So there are missing valuesin 3 columns, but not enough to make a difference so lets just drop them for now

# %%
zillow = zillow.dropna()
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0      2061546          2.0         3.0                        1458.0  6037.0
# 1      1834372          1.0         2.0                        1421.0  6037.0
# 2      2121349          2.0         3.0                        1650.0  6037.0
# 3      2093710          1.0         2.0                         693.0  6037.0
# 4       496818          0.0         0.0                        1378.0  6037.0
# ...        ...          ...         ...                           ...     ...
# 20343  1624472          3.0         3.0                        2632.0  6111.0
# 20344   997928          3.0         4.0                        2734.0  6111.0
# 20345   849307          2.5         4.0                        2314.0  6111.0
# 20346  2416171          2.0         2.0                        1178.0  6111.0
# 20347  2163429          2.0         3.0                        1278.0  6111.0
#
#        taxvaluedollarcnt  taxamount  taxrate  FIPS         Name State
# 0               136104.0    2319.90     1.70  6037  Los Angeles    CA
# 1                35606.0     543.69     1.53  6037  Los Angeles    CA
# 2               614000.0    7673.19     1.25  6037  Los Angeles    CA
# 3               274237.0    3267.47     1.19  6037  Los Angeles    CA
# 4               168828.0    2135.39     1.26  6037  Los Angeles    CA
# ...                  ...        ...      ...   ...          ...   ...
# 20343           795992.0    8449.92     1.06  6111      Ventura    CA
# 20344           897000.0    9585.08     1.07  6111      Ventura    CA
# 20345           485364.0    9549.08     1.97  6111      Ventura    CA
# 20346           169908.0    1779.86     1.05  6111      Ventura    CA
# 20347           468000.0    5396.08     1.15  6111      Ventura    CA
#
# [20294 rows x 11 columns]

# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20294 entries, 0 to 20347
# Data columns (total 11 columns):
# id                              20294 non-null int64
# bathroomcnt                     20294 non-null float64
# bedroomcnt                      20294 non-null float64
# calculatedfinishedsquarefeet    20294 non-null float64
# fips                            20294 non-null float64
# taxvaluedollarcnt               20294 non-null float64
# taxamount                       20294 non-null float64
# taxrate                         20294 non-null float64
# FIPS                            20294 non-null int64
# Name                            20294 non-null object
# State                           20294 non-null object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Also lets make sure bedroomcnt needs to be a float

# %%
zillow.bedroomcnt.value_counts()
# Out:
# 3.0     8220
# 2.0     5103
# 4.0     4633
# 5.0     1162
# 1.0      874
# 6.0      183
# 0.0       86
# 7.0       27
# 9.0        2
# 11.0       1
# 10.0       1
# 8.0        1
# 12.0       1
# Name: bedroomcnt, dtype: int64

# %%
zillow.bedroomcnt = zillow.bedroomcnt.astype('int')
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0      2061546          2.0           3                        1458.0  6037.0
# 1      1834372          1.0           2                        1421.0  6037.0
# 2      2121349          2.0           3                        1650.0  6037.0
# 3      2093710          1.0           2                         693.0  6037.0
# 4       496818          0.0           0                        1378.0  6037.0
# ...        ...          ...         ...                           ...     ...
# 20343  1624472          3.0           3                        2632.0  6111.0
# 20344   997928          3.0           4                        2734.0  6111.0
# 20345   849307          2.5           4                        2314.0  6111.0
# 20346  2416171          2.0           2                        1178.0  6111.0
# 20347  2163429          2.0           3                        1278.0  6111.0
#
#        taxvaluedollarcnt  taxamount  taxrate  FIPS         Name State
# 0               136104.0    2319.90     1.70  6037  Los Angeles    CA
# 1                35606.0     543.69     1.53  6037  Los Angeles    CA
# 2               614000.0    7673.19     1.25  6037  Los Angeles    CA
# 3               274237.0    3267.47     1.19  6037  Los Angeles    CA
# 4               168828.0    2135.39     1.26  6037  Los Angeles    CA
# ...                  ...        ...      ...   ...          ...   ...
# 20343           795992.0    8449.92     1.06  6111      Ventura    CA
# 20344           897000.0    9585.08     1.07  6111      Ventura    CA
# 20345           485364.0    9549.08     1.97  6111      Ventura    CA
# 20346           169908.0    1779.86     1.05  6111      Ventura    CA
# 20347           468000.0    5396.08     1.15  6111      Ventura    CA
#
# [20294 rows x 11 columns]

# %% [markdown]
# ## There are some duplicate columns so lets get rid of those

# %%
zillow = zillow.drop(columns='fips')
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  \
# 0      2061546          2.0           3                        1458.0
# 1      1834372          1.0           2                        1421.0
# 2      2121349          2.0           3                        1650.0
# 3      2093710          1.0           2                         693.0
# 4       496818          0.0           0                        1378.0
# ...        ...          ...         ...                           ...
# 20343  1624472          3.0           3                        2632.0
# 20344   997928          3.0           4                        2734.0
# 20345   849307          2.5           4                        2314.0
# 20346  2416171          2.0           2                        1178.0
# 20347  2163429          2.0           3                        1278.0
#
#        taxvaluedollarcnt  taxamount  taxrate  FIPS         Name State
# 0               136104.0    2319.90     1.70  6037  Los Angeles    CA
# 1                35606.0     543.69     1.53  6037  Los Angeles    CA
# 2               614000.0    7673.19     1.25  6037  Los Angeles    CA
# 3               274237.0    3267.47     1.19  6037  Los Angeles    CA
# 4               168828.0    2135.39     1.26  6037  Los Angeles    CA
# ...                  ...        ...      ...   ...          ...   ...
# 20343           795992.0    8449.92     1.06  6111      Ventura    CA
# 20344           897000.0    9585.08     1.07  6111      Ventura    CA
# 20345           485364.0    9549.08     1.97  6111      Ventura    CA
# 20346           169908.0    1779.86     1.05  6111      Ventura    CA
# 20347           468000.0    5396.08     1.15  6111      Ventura    CA
#
# [20294 rows x 10 columns]

# %% [markdown]
# ## Lets also clarify the names of some of the columns

# %%
zillow = zillow.rename(columns={'calculatedfinishedsquarefeet': 'squarefeet', 'Name': 'County'})
zillow
# Out:
#             id  bathroomcnt  bedroomcnt  squarefeet  taxvaluedollarcnt  \
# 0      2061546          2.0           3      1458.0           136104.0
# 1      1834372          1.0           2      1421.0            35606.0
# 2      2121349          2.0           3      1650.0           614000.0
# 3      2093710          1.0           2       693.0           274237.0
# 4       496818          0.0           0      1378.0           168828.0
# ...        ...          ...         ...         ...                ...
# 20343  1624472          3.0           3      2632.0           795992.0
# 20344   997928          3.0           4      2734.0           897000.0
# 20345   849307          2.5           4      2314.0           485364.0
# 20346  2416171          2.0           2      1178.0           169908.0
# 20347  2163429          2.0           3      1278.0           468000.0
#
#        taxamount  taxrate  FIPS       County State
# 0        2319.90     1.70  6037  Los Angeles    CA
# 1         543.69     1.53  6037  Los Angeles    CA
# 2        7673.19     1.25  6037  Los Angeles    CA
# 3        3267.47     1.19  6037  Los Angeles    CA
# 4        2135.39     1.26  6037  Los Angeles    CA
# ...          ...      ...   ...          ...   ...
# 20343    8449.92     1.06  6111      Ventura    CA
# 20344    9585.08     1.07  6111      Ventura    CA
# 20345    9549.08     1.97  6111      Ventura    CA
# 20346    1779.86     1.05  6111      Ventura    CA
# 20347    5396.08     1.15  6111      Ventura    CA
#
# [20294 rows x 10 columns]

# %% [markdown]
# ## Now lets make a function that gets the data for us and cleans it.

# %%
def acquire_and_prep_data():
    zillow = acquire.get_data()

    zillow = zillow.drop_duplicates()
    zillow = zillow.dropna()
    zillow = zillow.drop(columns='fips')
    zillow.bedroomcnt = zillow.bedroomcnt.astype('int')
    zillow = zillow.rename(columns={'calculatedfinishedsquarefeet': 'squarefeet', 'Name': 'County'})

    return zillow

# %%
prep.acquire_and_prep_data()
# Out:
#             id  bathroomcnt  bedroomcnt  squarefeet  taxvaluedollarcnt  \
# 0      2061546          2.0           3      1458.0           136104.0
# 1      1834372          1.0           2      1421.0            35606.0
# 2      2121349          2.0           3      1650.0           614000.0
# 3      2093710          1.0           2       693.0           274237.0
# 4       496818          0.0           0      1378.0           168828.0
# ...        ...          ...         ...         ...                ...
# 20343  1624472          3.0           3      2632.0           795992.0
# 20344   997928          3.0           4      2734.0           897000.0
# 20345   849307          2.5           4      2314.0           485364.0
# 20346  2416171          2.0           2      1178.0           169908.0
# 20347  2163429          2.0           3      1278.0           468000.0
#
#        taxamount  taxrate  FIPS       County State
# 0        2319.90     1.70  6037  Los Angeles    CA
# 1         543.69     1.53  6037  Los Angeles    CA
# 2        7673.19     1.25  6037  Los Angeles    CA
# 3        3267.47     1.19  6037  Los Angeles    CA
# 4        2135.39     1.26  6037  Los Angeles    CA
# ...          ...      ...   ...          ...   ...
# 20343    8449.92     1.06  6111      Ventura    CA
# 20344    9585.08     1.07  6111      Ventura    CA
# 20345    9549.08     1.97  6111      Ventura    CA
# 20346    1779.86     1.05  6111      Ventura    CA
# 20347    5396.08     1.15  6111      Ventura    CA
#
# [20294 rows x 10 columns]
